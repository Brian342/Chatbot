# %% [markdown]
# <a href="https://colab.research.google.com/github/Brian342/Chatbot/blob/main/Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries and packages
import numpy as np
import time
import os
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
